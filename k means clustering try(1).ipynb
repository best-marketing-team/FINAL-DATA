# %%
import pandas as pd

# %%
sheet0 = pd.read_excel('./final_review.xlsx', sheet_name = 0)
sheet1 = pd.read_excel('./final_review.xlsx', sheet_name = 1)
sheet2 = pd.read_excel('./final_review.xlsx', sheet_name = 2)
sheet3 = pd.read_excel('./final_review.xlsx', sheet_name = 3)
sheet4 = pd.read_excel('./final_review.xlsx', sheet_name = 4)
sheet5 = pd.read_excel('./final_review.xlsx', sheet_name = 5)
sheet6 = pd.read_excel('./final_review.xlsx', sheet_name = 6)
sheet7 = pd.read_excel('./final_review.xlsx', sheet_name = 7)
sheet8 = pd.read_excel('./final_review.xlsx', sheet_name = 8)
sheet9 = pd.read_excel('./final_review.xlsx', sheet_name = 9)
sheet10 = pd.read_excel('./final_review.xlsx', sheet_name = 10)

# %%
df = pd.concat([sheet0,sheet1,sheet2,sheet3,sheet4,sheet5,sheet6,sheet7,sheet8,sheet9,sheet10],axis=1)

# %%
df
# Out:
#      튼튼닷컴 밀크씨슬 [6개월분], 1000mg, 1개, 180캡슐 26,900원 지앤씨 밀크시슬, 60정, 1개   \
# 0                                           리베카               겨울온기
# 1                                           제주남                하*희
# 2                                          나비아씨              솔직냥집사
# 3                                           박*하                윤*우
# 4                                           유*한                이*인
# ...                                          ...                ...
# 7085                                         NaN                NaN
# 7086                                         NaN                NaN
# 7087                                         NaN                NaN
# 7088                                         NaN                NaN
# 7089                                         NaN                NaN
#
#      종근당건강 헬씨칸 밀크씨슬 영양제, 30정, 2개 23,270원 보뚜 간에좋은 밀크씨슬 프리미엄, 150정, 1개 29,900  \
# 0                                   서*아                                홍*환
# ...

# %%
len(df.columns)
name_label = df.columns
name_label=list(name_label)
# Out:
# 150

# %%
name_label = pd.Series(name_label)

# %%
type(name_label)
# Out:
# pandas.core.series.Series

# %%
name_label.index = range(150)

# %%
name_label
# Out:
# 0         튼튼닷컴 밀크씨슬 [6개월분], 1000mg, 1개, 180캡슐 26,900원
# 1                                  지앤씨 밀크시슬, 60정, 1개
# 2                 종근당건강 헬씨칸 밀크씨슬 영양제, 30정, 2개 23,270원
# 3                  보뚜 간에좋은 밀크씨슬 프리미엄, 150정, 1개 29,900
# 4            Now Foods 실리마린 밀크 시슬 추출물 300mg 베지 캡슐, 1개
#                             ...
# 145               종근당건강 시원하다 전립쎈 쏘팔메토, 60정, 2개 25,310
# 146    Now Foods 쏘 팔메토 베리즈 550mg 캡슐, 250개입, 1개 16,700
# 147                     메이플트리 쏘팔메토 맥스, 90정, 2개 31,080
# 148           쏘팔코사놀 1000 쏘팔메토 옥타코사놀, 130정, 1세트 99,800
# 149                통라이프 쏘팔메토 골드 1000, 60캡슐, 1개 15,210
# Length: 150, dtype: object

# %%
a_list = []
for i in range(10+1):
    a_list.append('milk'+str(i))
for i in range(11, 20+1):
    a_list.append('glu'+str(i-10))
for i in range(21, 31+1):
    a_list.append('col'+str(i-20))
for i in range(32, 40+1):
    a_list.append('msm'+str(i-31))
for i in range(41, 59+1):
    a_list.append('prebio'+str(i-40))
for i in range(60, 69+1):
    a_list.append('cre'+str(i-59))
for i in range(70, 79+1):
    a_list.append('coQ'+str(i-69))
for i in range(80, 108+1):
    a_list.append('omega'+str(i-79))
for i in range(109, 121+1):
    a_list.append('pro'+str(i-108))
for i in range(122, 143+1):
    a_list.append('lut'+str(i-121))
for i in range(144, 150+1):
    a_list.append('saw'+str(i-143))

# %%
a_list
# Out:
# ['milk0',
#  'milk1',
#  'milk2',
#  'milk3',
#  'milk4',
#  'milk5',
#  'milk6',
#  'milk7',
#  'milk8',
#  'milk9',
#  'milk10',
#  'glu1',
#  'glu2',
#  'glu3',
#  'glu4',
#  'glu5',
#  'glu6',
#  'glu7',
#  'glu8',
#  'glu9',
#  'glu10',
#  'col1',
#  'col2',
#  'col3',
#  'col4',
#  'col5',
#  'col6',
#  'col7',
#  'col8',
#  'col9',
#  'col10',
#  'col11',
#  'msm1',
#  'msm2',
#  'msm3',
#  'msm4',
#  'msm5',
#  'msm6',
#  'msm7',
#  'msm8',
#  'msm9',
#  'prebio1',
#  'prebio2',
#  'prebio3',
#  'prebio4',
#  'prebio5',
#  'prebio6',
#  'prebio7',
#  'prebio8',
#  'prebio9',
#  'prebio10',
#  'prebio11',
#  'prebio12',
#  'prebio13',
#  'prebio14',
#  'prebio15',
#  'prebio16',
#  'prebio17',
#  'prebio18',
#  'prebio19',
#  'cre1',
#  'cre2',
#  'cre3',
#  'cre4',
#  'cre5',
#  'cre6',
#  'cre7',
#  'cre8',
#  'cre9',
#  'cre10',
#  'coQ1',
#  'coQ2',
#  'coQ3',
#  'coQ4',
#  'coQ5',
#  'coQ6',
#  'coQ7',
#  'coQ8',
#  'coQ9',
#  'coQ10',
#  'omega1',
#  'omega2',
# ...

# %%
name_label.index = a_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4eff25138af4> in <module>
# ----> 1 name_label.index = a_list
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     422         if not fastpath:
#     423             # The ensure_index call above ensures we have an Index object
# --> 424             self._mgr.set_axis(axis, labels)
#     425
#     426     # ndarray compatibility
#
# ...

# %%
name_label
# Out:
# code0    튼튼닷컴 밀크씨슬 [6개월분], 1000mg, 1개, 180캡슐 26,900원
# code1                             지앤씨 밀크시슬, 60정, 1개
# code2            종근당건강 헬씨칸 밀크씨슬 영양제, 30정, 2개 23,270원
# code3             보뚜 간에좋은 밀크씨슬 프리미엄, 150정, 1개 29,900
# code4       Now Foods 실리마린 밀크 시슬 추출물 300mg 베지 캡슐, 1개
# code5                                     뉴트리데이 프리미엄
# code6                  GNM자연의품격 건강한 간 밀크씨슬, 132정, 1개
# code7                   GNM자연의품격 건강한 간 밀크씨슬, 30정, 6개
# code8              Swanson 밀크 시슬 500mg 캡슐, 100개입, 1개
# code9                  한미헬스케어 간에 좋은 밀크씨슬 골드, 90정, 2개
# dtype: object

# %%
df.columns = a_list

# %%
df
# Out:
#      code0   code1      code2      code3  code4    code5    code6   code7  \
# 0     리베카    겨울온기        서*아        홍*환    쿸쿸쿸     실천의힘   UNIUNI     칠치링
# 1     제주남     하*희      집노예도비        다없대    전천도      엄*주    또또뿌니율   또또뿌니율
# 2    나비아씨   솔직냥집사      또또뿌니율    esmooom    오*진    웅장해진다     이이이삼     오*근
# 3     박*하     윤*우       좋은날들      노란잠수함   까페타임     지앤지앤      박*숙     혼밥녀
# 4     유*한     이*인       좋은날들   듀륏cherry    박*대     보석마미      이*영     혼밥녀
# ..     ...     ...        ...        ...    ...      ...      ...     ...
# 995    NaN     NaN       최*람        최*호    김*애   jj7577       NaN    권*경
# 996    NaN     NaN       듀듐칫        한*섭    김*목      박*근       NaN    박*승
# 997    NaN     NaN  Yoonimom        오*준    황*원      정*공       NaN    배미자
# 998    NaN     NaN       송*진        유*근    심*준      신*철       NaN    정*미
# 999    NaN     NaN       송*자        진*현    이*주     산골다래       NaN    박*혁
#
#       code8   code9
# 0      배*웅    리뷰홀릭
# 1      이*범   웅장해진다
# 2    웅장해진다     김*래
# ...

# %%
name_label.code0
# Out:
# '튼튼닷컴 밀크씨슬 [6개월분], 1000mg, 1개, 180캡슐 26,900원'

# %%
code0_user =  df.code0

# %%
code0_user
# Out:
# 0       리베카
# 1       제주남
# 2      나비아씨
# 3       박*하
# 4       유*한
#        ...
# 995      NaN
# 996      NaN
# 997      NaN
# 998      NaN
# 999      NaN
# Name: code0, Length: 1000, dtype: object
